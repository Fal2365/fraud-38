# %%
# Ensure lightgbm is installed
# !pip install lightgbm -q

# Load model and encoders
import joblib
import pandas as pd
import lightgbm as lgb

model = joblib.load("fraud_detection_model.jb")
encoders = joblib.load("label_encoder.jb")
df = pd.read_csv("transactions.csv")

# Print class distribution
print("Fraud label distribution:")
print(df['is_fraud'].value_counts())

# Show a sample of the dataset
df.head()

# %% [markdown]
# # Fraud Detection App - Notebook Version
# This notebook mirrors the logic of the Streamlit app for loading the model, encoder, and testing predictions on a dataset.

# %%
import pandas as pd
import joblib
from geopy.distance import geodesic
import lightgbm as lgb
import warnings
warnings.filterwarnings('ignore')

# %%
# Load model and encoders
model = joblib.load('fraud_detection_model.jb')
encoder = joblib.load('label_encoder.jb')

# %%
# Load dataset
df = pd.read_csv('transactions.csv')
df.head()

# %%
# Compute distance using geodesic
df['distance'] = df.apply(lambda row: geodesic((row['lat'], row['long']), (row['merch_lat'], row['merch_long'])).km, axis=1)

# %%
# Process and encode features
df['cc_num'] = df['cc_num'].apply(lambda x: hash(str(x)) % (10 ** 2))
df['gender'] = df['gender'].str.capitalize()
categorical_cols = ['merchant', 'category', 'gender']
for col in categorical_cols:
    df[col] = df[col].apply(lambda x: x if x in encoder[col].classes_ else '<unknown>')
    if '<unknown>' not in encoder[col].classes_:
        encoder[col].classes_ = list(encoder[col].classes_) + ['<unknown>']
    df[col] = encoder[col].transform(df[col])

# %%
# Prepare input features
X = df[['merchant', 'category', 'amt', 'distance', 'hour', 'day', 'month', 'gender', 'cc_num']]

# %%
# Predict fraudulence
df['predicted'] = model.predict(X)
df[['merchant', 'category', 'amt', 'predicted']].head(10)

# %%
# Test model on transactions that are labeled as fraud (is_fraud == 1)
fraud_cases = df[df['is_fraud'] == 1].copy()
fraud_cases = fraud_cases.drop(columns=['is_fraud'])

# Encode categorical columns using loaded encoders
categorical_cols = ['merchant', 'category', 'gender']
for col in categorical_cols:
    if col in fraud_cases.columns:
        fraud_cases[col] = fraud_cases[col].apply(lambda x: x if x in encoders[col].classes_ else '__unknown__')
        fraud_cases[col] = encoders[col].transform(fraud_cases[col])

# Hash cc_num as in app
fraud_cases['cc_num'] = fraud_cases['cc_num'].apply(lambda x: hash(x) % (10 ** 2))

# Predict
predictions = model.predict(fraud_cases)
fraud_cases['predicted_label'] = predictions

# Display results
print("Sample Predictions on Fraudulent Transactions:")
fraud_cases[['merchant', 'category', 'amt', 'cc_num', 'predicted_label']].head(10)
